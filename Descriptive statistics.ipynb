# %% [markdown]
# # Descriptive statistics

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
income_df = pd.read_csv(r'D:\Full Stack Data Science With Gen AI & Agentic AI Notes\Notes\April\24 April\Descriptive statistics project\Income expenditure data.csv')

# %%
income_df.head()
# Out:
#    Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0             5000              8000                  3             2000
# 1             6000              7000                  2             3000
# 2            10000              4500                  2                0
# 3            10000              2000                  1                0
# 4            12500             12000                  2             3000
#
#    Annual_HH_Income Highest_Qualified_Member  No_of_Earning_Members
# 0             64200           Under-Graduate                      1
# 1             79920               Illiterate                      1
# 2            112800           Under-Graduate                      1
# 3             97200               Illiterate                      1
# 4            147000                 Graduate                      1

# %%
income_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Mthly_HH_Income           50 non-null     int64
#  1   Mthly_HH_Expense          50 non-null     int64
#  2   No_of_Fly_Members         50 non-null     int64
#  3   Emi_or_Rent_Amt           50 non-null     int64
#  4   Annual_HH_Income          50 non-null     int64
#  5   Highest_Qualified_Member  50 non-null     str
#  6   No_of_Earning_Members     50 non-null     int64
# dtypes: int64(6), str(1)
# memory usage: 3.4 KB

# %%
income_df.shape
# Out:
# (50, 7)

# %%
income_df.describe()
# Out:
#        Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# count        50.000000         50.000000          50.000000        50.000000
# mean      41558.000000      18818.000000           4.060000      3060.000000
# std       26097.908979      12090.216824           1.517382      6241.434948
# min        5000.000000       2000.000000           1.000000         0.000000
# 25%       23550.000000      10000.000000           3.000000         0.000000
# 50%       35000.000000      15500.000000           4.000000         0.000000
# 75%       50375.000000      25000.000000           5.000000      3500.000000
# max      100000.000000      50000.000000           7.000000     35000.000000
#
#        Annual_HH_Income  No_of_Earning_Members
# count      5.000000e+01              50.000000
# mean       4.900190e+05               1.460000
# std        3.201358e+05               0.734291
# min        6.420000e+04               1.000000
# ...

# %%
income_df.describe().T
# Out:
#                        count       mean            std      min       25%  \
# Mthly_HH_Income         50.0   41558.00   26097.908979   5000.0   23550.0
# Mthly_HH_Expense        50.0   18818.00   12090.216824   2000.0   10000.0
# No_of_Fly_Members       50.0       4.06       1.517382      1.0       3.0
# Emi_or_Rent_Amt         50.0    3060.00    6241.434948      0.0       0.0
# Annual_HH_Income        50.0  490019.04  320135.792123  64200.0  258750.0
# No_of_Earning_Members   50.0       1.46       0.734291      1.0       1.0
#
#                             50%       75%        max
# Mthly_HH_Income         35000.0   50375.0   100000.0
# Mthly_HH_Expense        15500.0   25000.0    50000.0
# No_of_Fly_Members           4.0       5.0        7.0
# Emi_or_Rent_Amt             0.0    3500.0    35000.0
# Annual_HH_Income       447420.0  594720.0  1404000.0
# No_of_Earning_Members       1.0       2.0        4.0

# %%
income_df.isna().any()
# Out:
# Mthly_HH_Income             False
# Mthly_HH_Expense            False
# No_of_Fly_Members           False
# Emi_or_Rent_Amt             False
# Annual_HH_Income            False
# Highest_Qualified_Member    False
# No_of_Earning_Members       False
# dtype: bool

# %%
income_df.isnull().sum()
# Out:
# Mthly_HH_Income             0
# Mthly_HH_Expense            0
# No_of_Fly_Members           0
# Emi_or_Rent_Amt             0
# Annual_HH_Income            0
# Highest_Qualified_Member    0
# No_of_Earning_Members       0
# dtype: int64

# %%
print(income_df['Mthly_HH_Expense'].mean())
# Out:
# 18818.0

# %%
print(income_df['Mthly_HH_Expense'].median())
# Out:
# 15500.0

# %%
print(income_df['Mthly_HH_Expense'].mode())
# Out:
# 0    25000
# Name: Mthly_HH_Expense, dtype: int64

# %%
print(income_df['Mthly_HH_Income'].mean())
# Out:
# 41558.0

# %%
print(income_df['Mthly_HH_Income'].median())
# Out:
# 35000.0

# %%
print(income_df['Mthly_HH_Income'].mode())
# Out:
# 0    45000
# Name: Mthly_HH_Income, dtype: int64

# %%
mth_exp_temp = pd.crosstab(index = income_df['Mthly_HH_Expense'], columns = 'count') # Compute a simple cross tabulation of two (or more) factors
mth_exp_temp.reset_index(inplace = True)
print(mth_exp_temp)
# Out:
# col_0  Mthly_HH_Expense  count
# 0                  2000      1
# 1                  4500      1
# 2                  5000      1
# 3                  6600      1
# 4                  7000      1
# 5                  8000      3
# 6                  9000      3
# 7                 10000      5
# 8                 10500      1
# 9                 12000      3
# 10                12300      1
# 11                13000      1
# 12                15000      3
# 13                16000      1
# 14                18000      1
# 15                19000      1
# 16                20000      6
# 17                22000      1
# 18                25000      8
# 19                30000      1
# 20                40000      2
# 21                45000      1
# 22                48000      1
# 23                50000      2

# %%
mth_exp_temp[mth_exp_temp['count'] == income_df.Mthly_HH_Expense.value_counts().max()]
# Out:
# col_0  Mthly_HH_Expense  count
# 18                25000      8

# %%
income_df['Highest_Qualified_Member'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Highest_Qualified_Member'>

# %%
income_df.plot(x = 'Mthly_HH_Income', y = 'Mthly_HH_Expense')
# Out:
# <Axes: xlabel='Mthly_HH_Income'>

# %%
income_df.plot(x = 'Mthly_HH_Income', y = 'Mthly_HH_Expense', kind = 'scatter')
# Out:
# <Axes: xlabel='Mthly_HH_Income', ylabel='Mthly_HH_Expense'>

# %%
print(income_df['Mthly_HH_Expense'].quantile(0.25))
# Out:
# 10000.0

# %%
print(income_df['Mthly_HH_Expense'].quantile(0.50))
# Out:
# 15500.0

# %%
print(income_df['Mthly_HH_Expense'].quantile(0.75))
# Out:
# 25000.0

# %%
IQR = income_df['Mthly_HH_Expense'].quantile(0.75) - income_df['Mthly_HH_Expense'].quantile(0.25)
print(IQR)
# Out:
# 15000.0

# %%
pd.DataFrame(income_df.iloc[:, 0:5].std().to_frame()).T
# Out:
#    Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0     26097.908979      12090.216824           1.517382      6241.434948
#
#    Annual_HH_Income
# 0     320135.792123

# %%
pd.DataFrame(income_df.iloc[:, 0:5].var().to_frame()).T
# Out:
#    Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0     6.811009e+08      1.461733e+08           2.302449     3.895551e+07
#
#    Annual_HH_Income
# 0      1.024869e+11

# %%
income_df['Highest_Qualified_Member'].value_counts().to_frame().T
# Out:
# Highest_Qualified_Member  Graduate  Under-Graduate  Professional  \
# count                           19              10            10
#
# Highest_Qualified_Member  Post-Graduate  Illiterate
# count                                 6           5

# %%
income_df['No_of_Earning_Members'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='No_of_Earning_Members'>

# %%
print(income_df['Mthly_HH_Expense'].var())
# Out:
# 146173342.85714287

# %%
print(income_df['Mthly_HH_Expense'].std())
# Out:
# 12090.216824240286

# %%
print(income_df['Mthly_HH_Expense'].kurtosis())
# Out:
# 0.9424897886350738

# %%
print(income_df['Mthly_HH_Expense'].skew())
# Out:
# 1.1994608030097127

# %%
CV = income_df['Mthly_HH_Expense'].std()/income_df['Mthly_HH_Expense'].mean()
print(CV)
# Out:
# 0.6424814977277227
